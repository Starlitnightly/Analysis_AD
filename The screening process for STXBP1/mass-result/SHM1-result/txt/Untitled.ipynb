# %%
import pandas as pd
data=pd.read_csv("allPeptides.txt",sep='\t')
data.head()
# Out:
#   Raw file   Type  Charge        m/z        Mass  Uncalibrated m/z  \
# 0     test  MULTI       1  303.13338   302.12611         303.13397
# 1     test  MULTI       5  301.99415  1504.93440         301.99473
# 2     test  MULTI       7  300.99777  2099.93350         300.99835
# 3     test  MULTI       1  302.05547   301.04820         302.05606
# 4     test  MULTI       6  304.00857  1818.00780         304.00916
#
#    Number of data points  Number of scans  Number of isotopic peaks  PIF  \
# 0                      4                2                         2  NaN
# 1                      4                2                         2  NaN
# 2                     18               11                         2  NaN
# 3                     18               11                         2  NaN
# 4                     16                9                         2  NaN
#
#            ...           Modified sequence  Proteins  Score  PEP  Intensity  \
# ...
