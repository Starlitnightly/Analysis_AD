# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
import numpy as np                 #使用import导入模块numpy，并简写成np
import matplotlib.pyplot as plt    #使用import导入模块matplotlib.pyplot，并简写成plt
plt.figure(figsize=(8,4))          #设置绘图对象的宽度和高度
from PIL import Image
from pylab import *  
mpl.rcParams['font.sans-serif'] = ['SimHei'] #指定默认字体  
mpl.rcParams['axes.unicode_minus'] = False #解决保存图像是负号'-'显示为方块的问题   
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import xlrd

# %%
#x1:起始坐标
#x2：终止坐标
#y1：高度起始
#y2：高度终止
#sig: 标记
#min_x：x坐标轴的最小值，默认为0
def pltx(x1,x2,y1,y2,sig,min_x=0):
    x=np.ones((2))*x1
    y = np.arange(y1,y2,y2-y1-0.0001)
    plt.plot(x,y,label="$y$",color="black",linewidth=1)
    x=np.ones((2))*x2
    y = np.arange(y1,y2,y2-y1-0.0001)
    plt.plot(x,y,label="$y$",color="black",linewidth=1)
    x = np.arange(x1,x2+0.0001,x2-x1)
    y = y2+0*x
    plt.plot(x,y,label="$y$",color="black",linewidth=1)
    x0 = (x1+x2)/2
    y0=y2
    plt.annotate(r'%s'%sig, xy=(x0, y0), xycoords='data', xytext=(0, +1),
                     textcoords='offset points', fontsize=15,color="black")
    if(min_x!=0):
        plt.ylim(min_x,y2+y2/10)
    
pltx(0,1,2.1,2.7,'*',0.1)

# %%
import matplotlib.pylab as plt
import seaborn as sns
from scipy import stats

df = pd.read_csv('abmean.csv')
p=[]
for i in df['class']:
    if i=='CON':
        i='CTRL'
    p.append(i)
df['class']=p
plt.figure(figsize=(2,3))
ax = sns.violinplot(x="class", y="value", data=df,palette=['#4B7986','#89BABF'],
                    scale="area",scale_hue=True,width=0.5,
                    order=["CTRL", "SHED"])
ax.set_ylabel('Mean Intensity')
ax.set_xlabel('')
#plt.grid('True')
#plt.axvline(x='CON',ls="-",c="green")
ttest = stats.ttest_ind(df[df['class']=='CTRL']['value'], df[df['class']=='SHED']['value'])
max=df['value'].max()
if(ttest[1]<0.001):
    xing="***"   
elif(ttest[1]<0.01):
    xing="**"
elif(ttest[1]<0.05):
    xing="*"
else:
    xing=' '
print(ttest[1],xing)
if(xing!=''):
    pltx(0,1,max,max+0.1,xing)

#ax.tick_params(labelsize=15)

plt.savefig("mean1.png",dpi=300,bbox_inches = 'tight')
# Out:
# 0.042474114292337876 *

# %%
df = pd.read_csv('sf2.2.csv')
p=[]
for i in df['class']:
    if i=='CON':
        i='CTRL'
    p.append(i)
df['class']=p
plt.figure(figsize=(2,3))
ax = sns.violinplot(x="class", y="value", data=df,palette=['#4B7986','#89BABF'],
                    scale="area",scale_hue=True,width=0.5,
                    order=["CTRL", "SHED"])
ax.set_ylabel('Average size')
ax.set_xlabel('')

ttest = stats.ttest_ind(df[df['class']=='CTRL']['value'], df[df['class']=='SHED']['value'])
max=df['value'].max()
if(ttest[1]<0.001):
    xing="***"   
elif(ttest[1]<0.01):
    xing="**"
elif(ttest[1]<0.05):
    xing="*"
else:
    xing=' '
print(ttest[1],xing)
if(xing!=''):
    pltx(0,1,max,max+0.1,xing)
plt.savefig("aver.png",dpi=300,bbox_inches = 'tight')
# Out:
# 0.04024634597818897 *

# %%
df = pd.read_csv('sf4.1.csv')
p=[]
for i in df['class']:
    if i=='CON':
        i='CTRL'
    p.append(i)
df['class']=p
plt.figure(figsize=(3,3))
ax = sns.violinplot(x="class", y="value", data=df,palette=['#4B7986','#89BABF'],
                    scale="area",scale_hue=True,width=0.5,
                    order=["CTRL", "SHED"])
ax.set_ylabel('NESSL BODY')
ax.set_xlabel('')
ttest = stats.ttest_ind(df[df['class']=='CTRL']['value'], df[df['class']=='SHED']['value'])
max=int(df['value'].max())
print(max)
if(ttest[1]<0.001):
    xing="***"   
elif(ttest[1]<0.01):
    xing="**"
elif(ttest[1]<0.05):
    xing="*"
else:
    xing=' '
print(ttest[1],xing)
if(xing!=''):
    pltx(0,1,max,max+0.1,xing)
plt.savefig("nessl-1.png",dpi=300,bbox_inches = 'tight')
# Out:
# 3087
# 0.0024306079973859447 **

# %%
df = pd.read_csv('sf4.2.csv')
p=[]
for i in df['class']:
    if i=='CON':
        i='CTRL'
    p.append(i)
df['class']=p
plt.figure(figsize=(3,3))
ax = sns.violinplot(x="class", y="value", data=df,palette=['#4B7986','#89BABF'],
                    scale="area",scale_hue=True,width=0.5,
                    order=["CTRL", "SHED"])
ax.set_ylabel('NESSL BODY')
ax.set_xlabel('')
ttest = stats.ttest_ind(df[df['class']=='CTRL']['value'], df[df['class']=='SHED']['value'])
max=df['value'].max()
print(max)
if(ttest[1]<0.001):
    xing="***"   
elif(ttest[1]<0.01):
    xing="**"
elif(ttest[1]<0.05):
    xing="*"
else:
    xing=' '
print(ttest[1],xing)
if(xing!=''):
    pltx(0,1,max,max+0.1,xing)
plt.savefig("nessl-2.png",dpi=300,bbox_inches = 'tight')
# Out:
# 4799
# 0.006515487955951222 **

# %%
df = pd.read_csv('sf4.3.csv')
p=[]
for i in df['class']:
    if i=='CON':
        i='CTRL'
    p.append(i)
df['class']=p
plt.figure(figsize=(2,3))
ax = sns.violinplot(x="class", y="value", data=df,palette=['#4B7986','#89BABF'],
                    scale="area",scale_hue=True,width=0.5,
                    order=["CTRL", "SHED"])
ax.set_ylabel('The Mean Intensity\nof RBFOX3 positive\ncell to SAMP8+salt')
ax.set_xlabel('')
ttest = stats.ttest_ind(df[df['class']=='CTRL']['value'], df[df['class']=='SHED']['value'])
max=df['value'].max()
print(max)
if(ttest[1]<0.001):
    xing="***"   
elif(ttest[1]<0.01):
    xing="**"
elif(ttest[1]<0.05):
    xing="*"
else:
    xing=' '
print(ttest[1],xing)
if(xing!=''):
    pltx(0,1,max,max+0.1,xing)
plt.savefig("rbfox3-1.png",dpi=300,bbox_inches = 'tight')
# Out:
# 2.110700748
# 2.5657261808660423e-05 ***

# %%
df = pd.read_csv('sf4.4.csv')
p=[]
for i in df['class']:
    if i=='CON':
        i='CTRL'
    p.append(i)
df['class']=p
plt.figure(figsize=(2,3))
ax = sns.violinplot(x="class", y="value", data=df,palette=['#4B7986','#89BABF'],
                    scale="area",scale_hue=True,width=0.5,
                    order=["CTRL", "SHED"])
ax.set_ylabel('The Mean Intensity\nof RBFOX3 positive\ncell to SAMP8+salt')
ax.set_xlabel('')
ttest = stats.ttest_ind(df[df['class']=='CTRL']['value'], df[df['class']=='SHED']['value'])
max=df['value'].max()
if(ttest[1]<0.001):
    xing="***"   
elif(ttest[1]<0.01):
    xing="**"
elif(ttest[1]<0.05):
    xing="*"
else:
    xing=' '
print(ttest[1],xing)
if(xing!=''):
    pltx(0,1,max,max+0.1,xing,0.6)
plt.savefig("rbfox3-2.png",dpi=300,bbox_inches = 'tight')
# Out:
# 0.013655963073397918 *

# %%
df = pd.read_csv('sf.5.csv')
p=[]
for i in df['class']:
    if i=='CON':
        i='CTRL'
    p.append(i)
df['class']=p
dyt=[]
for i in df['if']:
    if (i not in dyt):
        dyt.append(i)
dyt

plt.figure(figsize=(10,5))
ax = sns.violinplot(x="if", y="value",hue="class", data=df,palette=['#4B7986','#89BABF'],
                    scale="area",split=True,
                    )
ax.set_ylabel('Cytokines Expression')
ax.set_xlabel('')
for i in range(len(dyt)):
    ttest = stats.ttest_ind(df[df['if']==dyt[i]][df[df['if']==dyt[i]]['class']=='CTRL']['value'], df[df['if']==dyt[i]][df[df['if']==dyt[i]]['class']=='SHED']['value'])
    max=df[df['if']==dyt[i]]['value'].max()
    if(ttest[1]<0.001):
        xing="***"   
    elif(ttest[1]<0.01):
        xing="**"
    elif(ttest[1]<0.05):
        xing="*"
    else:
        xing=' '
    print(ttest[1],xing)
    ax.text(i,max+0.5, xing,ha='center', va='bottom', fontsize=12)
plt.savefig("if.png",dpi=300,bbox_inches = 'tight')
# Out:
# 0.0032560562219063802 **
# 0.020952347758437163 *
# 0.014148349473457953 *
# 0.0002600260343467373 ***
# 0.020113405829957753 *
# 0.0053872285511741445 **
# 0.019098497705931573 *
# 0.35658108162659885
# 0.0004339676231618341 ***
# 0.008263967961443477 **
# 0.3172512270617674
# 0.008288271280337002 **

# %%
font1 = {
'weight' : 'bold',
'size'   : 18,
}

# %%
df = pd.read_csv('f6.1.csv')
p=[]
for i in df['class']:
    if i=='CON':
        i='CTRL'
    p.append(i)
df['class']=p
plt.figure(figsize=(2,3))
ax = sns.violinplot(x="class", y="value", data=df,palette=['#7C7C7C','#AD0B20'],
                    scale="area",scale_hue=True,width=0.5,
                    order=["CTRL", "SHED"])
ax.set_ylabel('The perim of\nmitochondria',font1)
ax.set_xlabel('')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
ttest = stats.ttest_ind(df[df['class']=='CTRL']['value'], df[df['class']=='SHED']['value'])
max=df['value'].max()
if(ttest[1]<0.001):
    xing="***"   
elif(ttest[1]<0.01):
    xing="**"
elif(ttest[1]<0.05):
    xing="*"
else:
    xing=' '
print(ttest[1],xing)
if(xing!=''):
    pltx(0,1,max,max+0.1,xing)
plt.savefig("mi-1.png",dpi=300,bbox_inches = 'tight')
# Out:
# 0.0015193818523776192 **

# %%
df = pd.read_csv('f6.2.csv')
p=[]
for i in df['class']:
    if i=='CON':
        i='CTRL'
    p.append(i)
df['class']=p
plt.figure(figsize=(2,3))
ax = sns.violinplot(x="class", y="value", data=df,palette=['#7C7C7C','#AD0B20'],
                    scale="area",scale_hue=True,width=0.5,
                    order=["CTRL", "SHED"])
ax.set_ylabel('Average size(pixel)',font1)
ax.set_xlabel('')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
ttest = stats.ttest_ind(df[df['class']=='CTRL']['value'], df[df['class']=='SHED']['value'])
max=df['value'].max()
if(ttest[1]<0.001):
    xing="***"   
elif(ttest[1]<0.01):
    xing="**"
elif(ttest[1]<0.05):
    xing="*"
else:
    xing=' '
print(ttest[1],xing)
if(xing!=''):
    pltx(0,1,max,max+0.1,xing)
plt.savefig("mi-2.png",dpi=300,bbox_inches = 'tight')
# Out:
# 0.03139367219573887 *

# %%
df = pd.read_csv('f6.3.csv')
p=[]
for i in df['class']:
    if i=='CON':
        i='CTRL'
    p.append(i)
df['class']=p
plt.figure(figsize=(2,3))
ax = sns.violinplot(x="class", y="value", data=df,palette=['#7C7C7C','#AD0B20'],
                    scale="area",scale_hue=True,width=0.5,
                    order=["CTRL", "SHED"])
ax.set_ylabel('The number of\nmitochondria',font1)
ax.set_xlabel('')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
ttest = stats.ttest_ind(df[df['class']=='CTRL']['value'], df[df['class']=='SHED']['value'])
max=df['value'].max()
if(ttest[1]<0.001):
    xing="***"   
elif(ttest[1]<0.01):
    xing="**"
elif(ttest[1]<0.05):
    xing="*"
else:
    xing=' '
print(ttest[1],xing)
if(xing!=''):
    pltx(0,1,max,max+0.1,xing)
plt.savefig("mi-3.png",dpi=300,bbox_inches = 'tight')
# Out:
# 0.028660509694717208 *

# %%
df = pd.read_csv('f6.4.csv')
p=[]
for i in df['class']:
    if i=='CON':
        i='CTRL'
    p.append(i)
df['class']=p
plt.figure(figsize=(2,3))
ax = sns.violinplot(x="class", y="value", data=df,palette=['#7C7C7C','#AD0B20'],
                    scale="area",scale_hue=True,width=0.5,
                    order=["CTRL", "SHED"])
ax.set_ylabel('Degree of \nroundness',font1)
ax.set_xlabel('')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
ttest = stats.ttest_ind(df[df['class']=='CTRL']['value'], df[df['class']=='SHED']['value'])
max=df['value'].max()
if(ttest[1]<0.001):
    xing="***"   
elif(ttest[1]<0.01):
    xing="**"
elif(ttest[1]<0.05):
    xing="*"
else:
    xing=' '
print(ttest[1],xing)
if(xing!=''):
    pltx(0,1,max,max+0.1,xing,0.1)
plt.savefig("mi-4.png",dpi=300,bbox_inches = 'tight')
# Out:
# 2.1242657828334242e-05 ***

# %%
df = pd.read_csv('f6.5.csv')
p=[]
for i in df['class']:
    if i=='CON':
        i='CTRL'
    p.append(i)
df['class']=p
plt.figure(figsize=(2,3))
ax = sns.violinplot(x="class", y="value", data=df,palette=['#7C7C7C','#AD0B20'],
                    scale="area",scale_hue=True,width=0.5,
                    order=["CTRL", "SHED"])
ax.set_ylabel('ATP(nm)',font1)
ax.set_xlabel('')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
ttest = stats.ttest_ind(df[df['class']=='CTRL']['value'], df[df['class']=='SHED']['value'])
max=df['value'].max()
if(ttest[1]<0.001):
    xing="***"   
elif(ttest[1]<0.01):
    xing="**"
elif(ttest[1]<0.05):
    xing="*"
else:
    xing=' '
print(ttest[1],xing)
if(xing!=''):
    pltx(0,1,max,max+0.1,xing)
plt.savefig("mi-5.png",dpi=300,bbox_inches = 'tight')
# Out:
# 0.03715196713851693 *

# %%
df = pd.read_csv('f6.6.csv')
p=[]
for i in df['class']:
    if i=='CON':
        i='CTRL'
    p.append(i)
df['class']=p
plt.figure(figsize=(2,3))
ax = sns.violinplot(x="class", y="value", data=df,palette=['#7C7C7C','#AD0B20'],
                    scale="area",scale_hue=True,width=0.5,
                    order=["CTRL", "SHED"])
ax.set_ylabel('JC1',font1)
ax.set_xlabel('')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
ttest = stats.ttest_ind(df[df['class']=='CTRL']['value'], df[df['class']=='SHED']['value'])
max=df['value'].max()
if(ttest[1]<0.001):
    xing="***"   
elif(ttest[1]<0.01):
    xing="**"
elif(ttest[1]<0.05):
    xing="*"
else:
    xing=' '
print(ttest[1],xing)
if(xing!=''):
    pltx(0,1,max,max+0.1,xing)
plt.savefig("mi-6.png",dpi=300,bbox_inches = 'tight')
# Out:
# 0.0010432603110038666 **

# %%
df = pd.read_csv('f2.1.csv')
p=[]
for i in df['class']:
    if i=='CON':
        i='CTRL'
    p.append(i)
df['class']=p
plt.figure(figsize=(2,3))
ax = sns.violinplot(x="class", y="value", data=df,palette=['#7C7C7C','#AD0B20'],
                    scale="area",scale_hue=True,width=0.5,
                    order=["CTRL", "SHED"])
ax.set_ylabel('Distance moved in \nCenter-point(cm)',font1)
ax.set_xlabel('')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
ttest = stats.ttest_ind(df[df['class']=='CTRL']['value'], df[df['class']=='SHED']['value'])
max=df['value'].max()
if(ttest[1]<0.001):
    xing="***"   
elif(ttest[1]<0.01):
    xing="**"
elif(ttest[1]<0.05):
    xing="*"
else:
    xing=' '
print(ttest[1],xing)
if(xing!=''):
    pltx(0,1,max,max+0.1,xing)
plt.savefig("f2.1.png",dpi=300,bbox_inches = 'tight')
# Out:
# 0.00037983689127442827 ***

# %%
df = pd.read_csv('f2.2.csv')
p=[]
for i in df['class']:
    if i=='CON':
        i='CTRL'
    p.append(i)
df['class']=p
plt.figure(figsize=(2,3))
ax = sns.violinplot(x="class", y="value", data=df,palette=['#7C7C7C','#AD0B20'],
                    scale="area",scale_hue=True,width=0.5,
                    order=["CTRL", "SHED"])
ax.set_ylabel('Velocity in \nCenter-point(cm/s)',font1)
ax.set_xlabel('')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
ttest = stats.ttest_ind(df[df['class']=='CTRL']['value'], df[df['class']=='SHED']['value'])
max=df['value'].max()
if(ttest[1]<0.001):
    xing="***"   
elif(ttest[1]<0.01):
    xing="**"
elif(ttest[1]<0.05):
    xing="*"
else:
    xing=' '
print(ttest[1],xing)
if(xing!=''):
    pltx(0,1,max,max+0.1,xing)
plt.savefig("f2.2.png",dpi=300,bbox_inches = 'tight')
# Out:
# 0.00017075034704788715 ***
